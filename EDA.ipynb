# %% [markdown]
# # Customer Sentiment Analysis — Exploratory Data Analysis
# Run this notebook after `src/preprocess.py` to explore the dataset before training.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')
df = pd.read_csv('../data/processed/clean_reviews.csv')
print(f'Total reviews: {len(df):,}')
df.head()

# %%
# Sentiment Distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

df['label'].value_counts().plot(kind='bar', ax=axes[0], color=['#d62728','#2ca02c'], rot=0)
axes[0].set_title('Sentiment Distribution')
axes[0].set_ylabel('Count')

df['label'].value_counts().plot(kind='pie', ax=axes[1], autopct='%1.1f%%',
                                 colors=['#d62728','#2ca02c'], startangle=90)
axes[1].set_title('Sentiment %')
axes[1].set_ylabel('')

plt.tight_layout()
plt.savefig('../outputs/eda_sentiment_dist.png', dpi=150)
plt.show()

# %%
# Review Length Distribution
fig, ax = plt.subplots(figsize=(10, 4))
for label, color in [('Positive','#2ca02c'), ('Negative','#d62728')]:
    subset = df[df['label'] == label]['review_length']
    ax.hist(subset, bins=50, alpha=0.6, label=label, color=color)

ax.set_xlabel('Review Length (words)')
ax.set_ylabel('Count')
ax.set_title('Review Length by Sentiment')
ax.legend()
ax.set_xlim(0, 150)
plt.tight_layout()
plt.savefig('../outputs/eda_review_length.png', dpi=150)
plt.show()

print(df.groupby('label')['review_length'].describe())

# %%
# Sample reviews
print('== POSITIVE SAMPLES ==')
for t in df[df['label']=='Positive']['review_text'].sample(3).values:
    print('-', t[:200])

print('\n== NEGATIVE SAMPLES ==')
for t in df[df['label']=='Negative']['review_text'].sample(3).values:
    print('-', t[:200])
